# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
x=np.array([[2,3],[3,4],[6,6],[7,7]])
k_means=KMeans(n_clusters=2, random_state=0, n_init="auto")

# %%
k_means.fit(x)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
k_means.labels_
# Out:
# array([1, 1, 0, 0], dtype=int32)

# %%
values=k_means.predict([[2,3], [6,6]])

# %%
values
# Out:
# array([1, 0], dtype=int32)

# %%
k_means.cluster_centers_
# Out:
# array([[6.5, 6.5],
#        [2.5, 3.5]])

# %%
clusters = {}
for i, label in enumerate(k_means.labels_):
    if label not in clusters:
        clusters[label] = []
    clusters[label].append(x[i])

for label, points in clusters.items():
    print(f"Cluster {label+1}: {points}")
# Out:
# Cluster 2: [array([2, 3]), array([3, 4])]
# Cluster 1: [array([6, 6]), array([7, 7])]

# %%
x1=np.array([2,4,10,12,3,20,30,11,25])

# %%
k_means1=KMeans(n_clusters=2, random_state=0, n_init="auto")
k_means1.fit(x1.reshape(-1,1))
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
pred=k_means1.predict([[2],[20]])
pred
# Out:
# array([0, 1], dtype=int32)

# %%
k_means1.cluster_centers_
# Out:
# array([[ 7.],
#        [25.]])

# %%
k_means1.labels_
# Out:
# array([0, 0, 0, 0, 0, 1, 1, 0, 1], dtype=int32)

# %%
clusters1 = {}
for i, label1 in enumerate(k_means1.labels_):
    if label1 not in clusters1:
        clusters1[label1] = []
    clusters1[label1].append(x1[i])

for label1, points in clusters1.items():
    print(f"Cluster {label1}: {points}")
# Out:
# Cluster 0: [np.int64(2), np.int64(4), np.int64(10), np.int64(12), np.int64(3), np.int64(11)]
# Cluster 1: [np.int64(20), np.int64(30), np.int64(25)]
